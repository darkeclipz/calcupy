# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sympy import symbols, sympify, latex, integrate, solve, solveset, Matrix, expand, factor, primitive, simplify, factor_list
from sympy.parsing.sympy_parser import parse_expr

# %%
M = np.array(Matrix(np.random.normal(0, 3, 500))).astype('float')
N = np.array(Matrix(np.random.normal(10, 3, 500))).astype('float')

# %%
fig = plt.figure(figsize=(8,8))
ax = plt.axes()
plt.tight_layout()
boxplot(M, positions=[1], boxprops={'color': 'purple', 'linewidth': 2}, medianprops={'color': 'purple', 'linewidth': 2}, widths=0.2)
boxplot(N, positions=[3], medianprops={'color': 'purple', 'linewidth': 2}, widths=0.6)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2018ea57780>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x201fb4ddba8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2018ea57438>],
#  'medians': [<matplotlib.lines.Line2D at 0x2018ea57e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2018ea57f60>],
#  'means': []}

# %%
plt.figure(figsize=(8,8))
hist(M, fc='purple', bins=int(np.sqrt(500)+1))
#grid()
# Out:
# (array([ 1.,  2.,  4.,  6.,  7., 11., 23., 34., 29., 53., 42., 46., 47.,
#         37., 36., 47., 28., 12., 15.,  8.,  6.,  1.,  5.]),
#  array([-8.93409472, -8.17350489, -7.41291506, -6.65232524, -5.89173541,
#         -5.13114559, -4.37055576, -3.60996593, -2.84937611, -2.08878628,
#         -1.32819646, -0.56760663,  0.1929832 ,  0.95357302,  1.71416285,
#          2.47475267,  3.2353425 ,  3.99593233,  4.75652215,  5.51711198,
#          6.2777018 ,  7.03829163,  7.79888146,  8.55947128]),
#  <a list of 23 Patch objects>)

# %%
plt.figure(figsize=(8,8))
hist(M, fc='purple', alpha=0.5, bins=int(np.sqrt(500)+1))
hist(N, fc='salmon', alpha=0.5, bins=int(np.sqrt(500)+1))
#grid()
# Out:
# (array([ 1.,  5.,  5.,  3., 10., 12., 13., 38., 32., 42., 52., 35., 53.,
#         34., 40., 33., 29., 24., 16.,  9.,  8.,  4.,  2.]),
#  array([ 1.23578226,  1.9594509 ,  2.68311954,  3.40678818,  4.13045682,
#          4.85412546,  5.5777941 ,  6.30146274,  7.02513138,  7.74880002,
#          8.47246866,  9.1961373 ,  9.91980593, 10.64347457, 11.36714321,
#         12.09081185, 12.81448049, 13.53814913, 14.26181777, 14.98548641,
#         15.70915505, 16.43282369, 17.15649233, 17.88016097]),
#  <a list of 23 Patch objects>)

# %%
np.random.normal(0, 1, 10)
# Out:
# array([-0.34418066,  0.48756486, -0.51190391,  0.32712884,  1.3299908 ,
#         0.85261622, -0.63709424, -0.18202305,  1.35780287,  0.64367802])

# %%
plt.figure(figsize=(8,8))
scatter(N,M,c='purple',lw=1)
axhline(np.mean(M),ls='dashed', c='gray', lw=2, alpha=0.5)
axvline(np.mean(N), ls='dashed', c='gray', lw=2, alpha=0.5)
title('Scatterplot of N~M')
# Out:
# Text(0.5, 1.0, 'Scatterplot of N~M')
